# %% [raw]
# ---
# description: This is basic module that generate all primes upto 'N' using Eratosthenes
#   sieve algorithm
# output-file: sieve.html
# title: sieve
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
primes = [p for p in sieve(100)]
test_eq(len(primes),25)

# %%
#| echo: false
#| output: asis
show_doc(sieve)
# Out:
# ---
#
# [source](https://github.com/nitinverma78/nbdev_sieve/blob/main/nbdev_sieve/sieve.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### sieve
#
# >      sieve (N=10)
#
# sieve of Eratosthenes
